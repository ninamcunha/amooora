# %% [markdown]
# # Exploring HuggingFace Topics

# %%
import pandas as pd

# %% [markdown]
# ## Connect GoogleDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load CSV's

# %%
therapist_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amooora/raw_data/text_labeled_bert.csv', keep_default_na=False)
therapist_df.head()
# Out:
#    label     score                             real_label
# 0      0  0.449480            Time Up and Future Meetings
# 1     34  0.431342  Managing and Increasing Energy Levels
# 2     18  0.298963         Voices and Perception of Sound
# 3     14  0.176815      Struggles and Desires in Learning
# 4     31  0.607514       Expressions of Happiness and Joy

# %%
classifier_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amooora/raw_data/topic_no_url.csv', keep_default_na=False)
classifier_df.head()
# Out:
#    label     real_label
# 0      7    Social Life
# 1      7    Social Life
# 2      7    Social Life
# 3      6  Entertainment
# 4      7    Social Life

# %% [markdown]
# ## Grouping labels

# %% [markdown]
# ### Therapist Model

# %%
# Counting labels %
label_counts = therapist_df["real_label"].value_counts(normalize=True, ascending=False)
label_counts
# Out:
# real_label
# Expressions of Happiness and Joy            0.484553
# Time Up and Future Meetings                 0.173606
# Managing and Increasing Energy Levels       0.080122
# See and Understanding Conversations         0.048143
# Dynamics of Meaningful Relationships        0.028092
# Fear and Reflection on Aging                0.024489
# Job Anxiety and Self-Reflection             0.023738
# Drinking Habits and Concerns                0.023221
# Struggles and Desires in Learning           0.022821
# Voices and Perception of Sound              0.020385
# Revisiting the Past Together                0.014380
# Gender Roles and Relationships              0.010309
# Struggles with Personal Change              0.007140
# Marriage Anxiety and Dependence             0.005155
# Understanding Depression and Its Roots      0.005038
# Pursuing Meaningful Personal Goals          0.003803
# Therapy and Father Relationships            0.003720
# Personal Growth and Decision-Making         0.002786
# Nurturing the inner child                   0.002586
# Open Conversation and Sharing               0.002502
# Father-Child Relationships and Authority    0.002335
# Self-Acceptance and Relationships           0.002052
# Understanding and Confronting Fear          0.001918
# Complex Mother-Sibling Relationships        0.001818
# Possibilities and Potential Outcomes        0.001084
# Exploring Emotional Hurt and Bitterness     0.000801
# Desires and Disappointments                 0.000667
# Safety and Self-Protection Strategies       0.000517
# Expressions of Anger and Frustration        0.000467
# Clarifying Meaning and Intent               0.000384
# Uncertainty and Understanding Issues        0.000317
# Desire to Escape and Leave                  0.000317
# Difficulties and Emotional Burdens          0.000267
# Guilt and Self-Blame Dynamics               0.000200
# Complex Emotions Toward Him                 0.000117
# Emotions of Crying and Tears                0.000100
# Inner Struggle and Helplessness             0.000050
# Name: proportion, dtype: float64

# %%
# Define labels below threshold
labels_to_replace = label_counts[label_counts < 0.07].index
labels_to_replace
# Out:
# Index(['See and Understanding Conversations',
#        'Dynamics of Meaningful Relationships', 'Fear and Reflection on Aging',
#        'Job Anxiety and Self-Reflection', 'Drinking Habits and Concerns',
#        'Struggles and Desires in Learning', 'Voices and Perception of Sound',
#        'Revisiting the Past Together', 'Gender Roles and Relationships',
#        'Struggles with Personal Change', 'Marriage Anxiety and Dependence',
#        'Understanding Depression and Its Roots',
#        'Pursuing Meaningful Personal Goals',
#        'Therapy and Father Relationships',
#        'Personal Growth and Decision-Making', 'Nurturing the inner child',
#        'Open Conversation and Sharing',
#        'Father-Child Relationships and Authority',
#        'Self-Acceptance and Relationships',
#        'Understanding and Confronting Fear',
#        'Complex Mother-Sibling Relationships',
#        'Possibilities and Potential Outcomes',
#        'Exploring Emotional Hurt and Bitterness',
#        'Desires and Disappointments', 'Safety and Self-Protection Strategies',
#        'Expressions of Anger and Frustration', 'Clarifying Meaning and Intent',
#        'Uncertainty and Understanding Issues', 'Desire to Escape and Leave',
#        'Difficulties and Emotional Burdens', 'Guilt and Self-Blame Dynamics',
#        'Complex Emotions Toward Him', 'Emotions of Crying and Tears',
#        'Inner Struggle and Helplessness'],
#       dtype='object', name='real_label')

# %%
# new column for grouped labels
therapist_df["grouped_label"] = therapist_df["real_label"].apply(lambda x: "Other" if x in labels_to_replace else x)

# %%
therapist_df.head()
# Out:
#    label     score                             real_label  \
# 0      0  0.449480            Time Up and Future Meetings
# 1     34  0.431342  Managing and Increasing Energy Levels
# 2     18  0.298963         Voices and Perception of Sound
# 3     14  0.176815      Struggles and Desires in Learning
# 4     31  0.607514       Expressions of Happiness and Joy
#
#                            grouped_label
# 0            Time Up and Future Meetings
# 1  Managing and Increasing Energy Levels
# 2                                  Other
# 3                                  Other
# 4       Expressions of Happiness and Joy

# %% [markdown]
# ## Grouping labels function

# %%
def group_labels_below(threshold, df):
  # Counting labels %
  label_counts = df["real_label"].value_counts(normalize=True, ascending=False)
  # Define labels below threshold
  labels_to_replace = label_counts[label_counts < threshold].index
  # new column for grouped labels
  df["grouped_label"] = df["real_label"].apply(lambda x: "Other" if x in labels_to_replace else x)
  return df

# %% [markdown]
# ### Testing function for both DataFrame

# %% [markdown]
# #### Classifier DF

# %%
classifier_grouped_df = group_labels_below(0.03, classifier_df)
classifier_grouped_df.grouped_label.unique()
# Out:
# array(['Social Life', 'Entertainment', 'Literature', 'Other',
#        'Home & Hobbies'], dtype=object)

# %% [markdown]
# #### Therapist DF

# %%
therapist_grouped_df = group_labels_below(0.03, therapist_df)
therapist_grouped_df.grouped_label.unique()
# Out:
# array(['Time Up and Future Meetings',
#        'Managing and Increasing Energy Levels', 'Other',
#        'Expressions of Happiness and Joy',
#        'See and Understanding Conversations'], dtype=object)

# %% [markdown]
# ## Save CSV

# %%
therapist_grouped_df.to_csv(
    '/content/drive/MyDrive/Colab Notebooks/amooora/raw_data/text_labeled_bert_grouped.csv',
    index=False,
    columns=therapist_grouped_df.columns
)

# %%
classifier_grouped_df.to_csv(
    '/content/drive/MyDrive/Colab Notebooks/amooora/raw_data/topic_no_url_grouped.csv',
    index=False,
    columns=classifier_grouped_df.columns
)

# %% [markdown]
# ## Encoding grouped labels

# %%
classifier_encoded_df = pd.get_dummies(
    classifier_grouped_df,
    columns=['grouped_label'],
    dtype=int,
    prefix='general'
).drop(columns=['label', 'real_label'])
classifier_encoded_df = pd.concat([classifier_grouped_df, classifier_encoded_df], axis=1)
classifier_encoded_df.head()
# Out:
#    label     real_label  grouped_label  general_Entertainment  \
# 0      7    Social Life    Social Life                      0
# 1      7    Social Life    Social Life                      0
# 2      7    Social Life    Social Life                      0
# 3      6  Entertainment  Entertainment                      1
# 4      7    Social Life    Social Life                      0
#
#    general_Home & Hobbies  general_Literature  general_Other  \
# 0                       0                   0              0
# 1                       0                   0              0
# 2                       0                   0              0
# 3                       0                   0              0
# 4                       0                   0              0
#
#    general_Social Life
# 0                    1
# 1                    1
# 2                    1
# 3                    0
# 4                    1

# %%
therapist_encoded_df = pd.get_dummies(
    therapist_grouped_df,
    columns=['grouped_label'],
    dtype=int,
    prefix='therapist'
).drop(columns=['score', 'label', 'real_label'])
therapist_encoded_df = pd.concat([therapist_grouped_df, therapist_encoded_df], axis=1).drop(columns=['score'])
therapist_encoded_df.head()
# Out:
#    label                             real_label  \
# 0      0            Time Up and Future Meetings
# 1     34  Managing and Increasing Energy Levels
# 2     18         Voices and Perception of Sound
# 3     14      Struggles and Desires in Learning
# 4     31       Expressions of Happiness and Joy
#
#                            grouped_label  \
# 0            Time Up and Future Meetings
# 1  Managing and Increasing Energy Levels
# 2                                  Other
# 3                                  Other
# 4       Expressions of Happiness and Joy
#
#    therapist_Expressions of Happiness and Joy  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           1
#
#    therapist_Managing and Increasing Energy Levels  therapist_Other  \
# 0                                                0                0
# 1                                                1                0
# 2                                                0                1
# 3                                                0                1
# 4                                                0                0
#
#    therapist_See and Understanding Conversations  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    therapist_Time Up and Future Meetings
# 0                                      1
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0

# %% [markdown]
# ### Renaming columns

# %%
classifier_encoded_df = classifier_encoded_df.rename(
    columns={
        'label': 'general_label',
        'real_label': 'general_real_label',
        'grouped_label': 'general_grouped_label'
    }
)
classifier_encoded_df.head()
# Out:
#    general_label general_real_label general_grouped_label  \
# 0              7        Social Life           Social Life
# 1              7        Social Life           Social Life
# 2              7        Social Life           Social Life
# 3              6      Entertainment         Entertainment
# 4              7        Social Life           Social Life
#
#    general_Entertainment  general_Home & Hobbies  general_Literature  \
# 0                      0                       0                   0
# 1                      0                       0                   0
# 2                      0                       0                   0
# 3                      1                       0                   0
# 4                      0                       0                   0
#
#    general_Other  general_Social Life
# 0              0                    1
# 1              0                    1
# 2              0                    1
# 3              0                    0
# 4              0                    1

# %%
therapist_encoded_df = therapist_encoded_df.rename(
    columns={
        'label': 'therapis_label',
        'real_label': 'therapist_real_label',
        'grouped_label': 'therapist_grouped_label'
    }
)
therapist_encoded_df.head()
# Out:
#    therapis_label                   therapist_real_label  \
# 0               0            Time Up and Future Meetings
# 1              34  Managing and Increasing Energy Levels
# 2              18         Voices and Perception of Sound
# 3              14      Struggles and Desires in Learning
# 4              31       Expressions of Happiness and Joy
#
#                  therapist_grouped_label  \
# 0            Time Up and Future Meetings
# 1  Managing and Increasing Energy Levels
# 2                                  Other
# 3                                  Other
# 4       Expressions of Happiness and Joy
#
#    therapist_Expressions of Happiness and Joy  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           1
#
#    therapist_Managing and Increasing Energy Levels  therapist_Other  \
# 0                                                0                0
# 1                                                1                0
# 2                                                0                1
# 3                                                0                1
# 4                                                0                0
#
#    therapist_See and Understanding Conversations  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    therapist_Time Up and Future Meetings
# 0                                      1
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0

# %% [markdown]
# ## Combining all with text_and_topics

# %%
text_topics_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amooora/raw_data/text_and_topics.csv', keep_default_na=False)

# %%
text_topics_df.head()
# Out:
#                                combined_preprocessed  answered_percent  \
# 0  would love think kind intellectual either dumb...             100.0
# 1  chef mean workaholic love cook regardless whet...              60.0
# 2  im ashamed much write public text online date ...              90.0
# 3  work library go school read thing write old de...              70.0
# 4  hey hows go currently vague profile know come ...              50.0
#
#    text_length  topic_0_from_five  topic_1_from_five  topic_2_from_five  \
# 0         1565           0.905500           0.023574           0.023639
# 1          815           0.027683           0.339134           0.027590
# 2         3728           0.914891           0.021284           0.021307
# 3          330           0.045781           0.045620           0.817402
# 4          496           0.031946           0.031976           0.872147
#
#    topic_3_from_five  topic_4_from_five  topic_0_from_two  topic_1_from_two
# 0           0.023778           0.023509          0.271588          0.728412
# 1           0.578125           0.027468          0.446532          0.553468
# 2           0.021207           0.021311          0.280111          0.719889
# 3           0.045673           0.045524          0.330528          0.669472
# 4           0.032119           0.031812          0.450953          0.549047

# %%
text_topics_encoded_df = pd.concat([text_topics_df, classifier_encoded_df, therapist_encoded_df], axis=1)
text_topics_encoded_df.iloc[:,10:].head()
# Out:
#    general_label general_real_label general_grouped_label  \
# 0              7        Social Life           Social Life
# 1              7        Social Life           Social Life
# 2              7        Social Life           Social Life
# 3              6      Entertainment         Entertainment
# 4              7        Social Life           Social Life
#
#    general_Entertainment  general_Home & Hobbies  general_Literature  \
# 0                      0                       0                   0
# 1                      0                       0                   0
# 2                      0                       0                   0
# 3                      1                       0                   0
# 4                      0                       0                   0
#
#    general_Other  general_Social Life  therapis_label  \
# 0              0                    1               0
# 1              0                    1              34
# 2              0                    1              18
# 3              0                    0              14
# 4              0                    1              31
#
#                     therapist_real_label  \
# 0            Time Up and Future Meetings
# 1  Managing and Increasing Energy Levels
# 2         Voices and Perception of Sound
# 3      Struggles and Desires in Learning
# 4       Expressions of Happiness and Joy
#
#                  therapist_grouped_label  \
# 0            Time Up and Future Meetings
# 1  Managing and Increasing Energy Levels
# 2                                  Other
# 3                                  Other
# 4       Expressions of Happiness and Joy
#
#    therapist_Expressions of Happiness and Joy  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           1
#
#    therapist_Managing and Increasing Energy Levels  therapist_Other  \
# 0                                                0                0
# 1                                                1                0
# 2                                                0                1
# 3                                                0                1
# 4                                                0                0
#
#    therapist_See and Understanding Conversations  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    therapist_Time Up and Future Meetings
# 0                                      1
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0

# %% [markdown]
# ### Save to CSV

# %%
text_topics_encoded_df.to_csv(
    '/content/drive/MyDrive/Colab Notebooks/amooora/raw_data/text_and_topics_classified_encoded.csv',
    index=False,
    columns=text_topics_encoded_df.columns
)

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/amooora/raw_data/text_and_topics_classified_encoded.csv', keep_default_na=False).iloc[:,10:]
# Out:
#        general_label general_real_label general_grouped_label  \
# 0                  7        Social Life           Social Life
# 1                  7        Social Life           Social Life
# 2                  7        Social Life           Social Life
# 3                  6      Entertainment         Entertainment
# 4                  7        Social Life           Social Life
# ...              ...                ...                   ...
# 59941              7        Social Life           Social Life
# 59942              7        Social Life           Social Life
# 59943              7        Social Life           Social Life
# 59944              7        Social Life           Social Life
# 59945              7        Social Life           Social Life
#
#        general_Entertainment  general_Home & Hobbies  general_Literature  \
# 0                          0                       0                   0
# 1                          0                       0                   0
# 2                          0                       0                   0
# 3                          1                       0                   0
# 4                          0                       0                   0
# ...                      ...                     ...                 ...
# 59941                      0                       0                   0
# 59942                      0                       0                   0
# 59943                      0                       0                   0
# 59944                      0                       0                   0
# 59945                      0                       0                   0
#
#        general_Other  general_Social Life  therapis_label  \
# 0                  0                    1               0
# 1                  0                    1              34
# 2                  0                    1              18
# 3                  0                    0              14
# 4                  0                    1              31
# ...              ...                  ...             ...
# 59941              0                    1              31
# 59942              0                    1               0
# 59943              0                    1               0
# 59944              0                    1              33
# 59945              0                    1              36
#
#                          therapist_real_label  \
# 0                 Time Up and Future Meetings
# 1       Managing and Increasing Energy Levels
# 2              Voices and Perception of Sound
# 3           Struggles and Desires in Learning
# 4            Expressions of Happiness and Joy
# ...                                       ...
# 59941        Expressions of Happiness and Joy
# 59942             Time Up and Future Meetings
# 59943             Time Up and Future Meetings
# 59944            Drinking Habits and Concerns
# 59945  Understanding Depression and Its Roots
#
#                      therapist_grouped_label  \
# 0                Time Up and Future Meetings
# 1      Managing and Increasing Energy Levels
# 2                                      Other
# 3                                      Other
# 4           Expressions of Happiness and Joy
# ...                                      ...
# 59941       Expressions of Happiness and Joy
# 59942            Time Up and Future Meetings
# 59943            Time Up and Future Meetings
# 59944                                  Other
# 59945                                  Other
#
#        therapist_Expressions of Happiness and Joy  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               1
# ...                                           ...
# 59941                                           1
# 59942                                           0
# 59943                                           0
# 59944                                           0
# 59945                                           0
#
#        therapist_Managing and Increasing Energy Levels  therapist_Other  \
# 0                                                    0                0
# 1                                                    1                0
# 2                                                    0                1
# 3                                                    0                1
# 4                                                    0                0
# ...                                                ...              ...
# 59941                                                0                0
# 59942                                                0                0
# 59943                                                0                0
# 59944                                                0                1
# 59945                                                0                1
#
#        therapist_See and Understanding Conversations  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 59941                                              0
# 59942                                              0
# 59943                                              0
# 59944                                              0
# 59945                                              0
#
#        therapist_Time Up and Future Meetings
# 0                                          1
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 59941                                      0
# 59942                                      1
# 59943                                      1
# 59944                                      0
# 59945                                      0
#
# [59946 rows x 16 columns]
